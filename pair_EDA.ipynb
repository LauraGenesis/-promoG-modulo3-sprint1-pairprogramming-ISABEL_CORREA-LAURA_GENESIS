# %%
import pandas as pd

import numpy as np

# %%
df=pd.read_csv("world-data-2023_part1.csv", index_col=0)

# %%
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %%
#1.Muestra las primeras 5 filas del conjunto de datos.
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
#2.Muestra las últimas 5 filas del conjunto de datos.
df.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %%
#3.Muestra una muestra aleatoria de 5 filas del conjunto de datos.
df.sample(5)
# Out:
#               Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 143            Russia                9           RU                13.30%
# 135  Papua New Guinea               20           PG                 2.60%
# 97              Libya                4           LY                 8.70%
# 24             Brunei               83           BN                 2.70%
# 129            Norway               15           NO                 2.70%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 143     17,098,240         1,454,000       11.50           7.0
# 135        462,840             4,000       27.07         675.0
# 97       1,759,540                 0       18.83         218.0
# 24           5,765             8,000       14.90         673.0
# 129        323,802            23,000       10.40          47.0
#
#       Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 143               Moscow     1,732,027  180.75          4.50%           RUB
# 135         Port Moresby         7,536  155.99          3.60%           PGK
# 97                   NaN        50,564  125.71          2.60%           LYD
# 24   Bandar Seri Begawan         7,664   99.03         -0.40%           BND
# 129                 Oslo        41,023  120.27          2.20%           NOK
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 143            1.57            49.80%         $0.59
# 135            3.56            74.10%         $1.36
# 97             2.24             0.10%         $0.11
# 24             1.85            72.10%         $0.37
# 129            1.56            33.20%         $1.78

# %%
#4.Muestra el número total de filas y columnas en el conjunto de datos.
df.shape
# Out:
# (195, 16)

# %%
#5.Muestra el nombre de todas las columnas en el conjunto de datos
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
#6.Muestra los valores únicos en la columna "Abbreviation".
df['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %%
#7.Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation
df['Abbreviation'].value_counts()
# Out:
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: Abbreviation, Length: 188, dtype: int64

# %%
#8. Verifica si hay valores nulos en el conjunto de datos.
df.isnull()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0      False             False         False                  False
# 1      False             False         False                  False
# 2      False             False         False                  False
# 3      False             False         False                  False
# 4      False             False         False                  False
# ..       ...               ...           ...                    ...
# 190    False             False         False                  False
# 191    False             False         False                  False
# 192    False             False         False                  False
# 193    False             False         False                  False
# 194    False             False         False                  False
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0             False              False       False         False
# 1             False              False       False         False
# 2             False              False       False         False
# 3             False               True       False         False
# 4             False              False       False         False
# ..              ...                ...         ...           ...
# 190           False              False       False         False
# 191           False              False       False         False
# 192           False              False       False         False
# 193           False              False       False         False
# 194           False              False       False         False
#
#      Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  Currency-Code  \
# 0                 False          False  False           False          False
# 1                 False          False  False           False          False
# 2                 False          False  False           False          False
# 3                 False          False   True            True          False
# 4                 False          False  False           False          False
# ..                  ...            ...    ...             ...            ...
# 190               False          False  False           False          False
# 191               False          False  False           False          False
# 192               False          False  False           False          False
# 193               False          False  False           False          False
# 194               False          False  False           False           True
#
#      Fertility Rate  Forested Area (%)  Gasoline Price
# 0             False              False           False
# 1             False              False           False
# 2             False              False           False
# 3             False              False           False
# 4             False              False           False
# ..              ...                ...             ...
# 190           False              False           False
# 191           False              False           False
# 192           False              False           False
# 193           False              False           False
# 194           False              False           False
#
# [195 rows x 16 columns]

# %%
#9.Verifica si hay valores no nulos en el conjunto de datos
df.notnull()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0       True              True          True                   True
# 1       True              True          True                   True
# 2       True              True          True                   True
# 3       True              True          True                   True
# 4       True              True          True                   True
# ..       ...               ...           ...                    ...
# 190     True              True          True                   True
# 191     True              True          True                   True
# 192     True              True          True                   True
# 193     True              True          True                   True
# 194     True              True          True                   True
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0              True               True        True          True
# 1              True               True        True          True
# 2              True               True        True          True
# 3              True              False        True          True
# 4              True               True        True          True
# ..              ...                ...         ...           ...
# 190            True               True        True          True
# 191            True               True        True          True
# 192            True               True        True          True
# 193            True               True        True          True
# 194            True               True        True          True
#
#      Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  Currency-Code  \
# 0                  True           True   True            True           True
# 1                  True           True   True            True           True
# 2                  True           True   True            True           True
# 3                  True           True  False           False           True
# 4                  True           True   True            True           True
# ..                  ...            ...    ...             ...            ...
# 190                True           True   True            True           True
# 191                True           True   True            True           True
# 192                True           True   True            True           True
# 193                True           True   True            True           True
# 194                True           True   True            True          False
#
#      Fertility Rate  Forested Area (%)  Gasoline Price
# 0              True               True            True
# 1              True               True            True
# 2              True               True            True
# 3              True               True            True
# 4              True               True            True
# ..              ...                ...             ...
# 190            True               True            True
# 191            True               True            True
# 192            True               True            True
# 193            True               True            True
# 194            True               True            True
#
# [195 rows x 16 columns]

# %%
#10.Muestra información general sobre el conjunto de datos.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %%
#11.Elimina una columna específica (por ejemplo, "Armed Forces size").
df.drop('Armed Forces size',axis=1)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0          652,230       32.49          93.0              Kabul         8,672
# 1           28,748       11.78         355.0             Tirana         4,536
# 2        2,381,741       24.28         213.0            Algiers       150,006
# 3              468        7.20         376.0   Andorra la Vella           469
# 4        1,246,700       40.73         244.0             Luanda        34,693
# ..             ...         ...           ...                ...           ...
# 190        912,050       17.88          58.0            Caracas       164,175
# 191        331,210       16.75          84.0              Hanoi       192,668
# 192        527,968       30.45         967.0              Sanaa        10,609
# 193        752,618       36.19         260.0             Lusaka         5,141
# 194        390,757       30.68         263.0             Harare        10,983
#
#           CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0       149.9          2.30%           AFN            4.47             2.10%
# 1      119.05          1.40%           ALL            1.62            28.10%
# 2      151.36          2.00%           DZD            3.02             0.80%
# 3         NaN            NaN           EUR            1.27            34.00%
# 4      261.73         17.10%           AOA            5.52            46.30%
# ..        ...            ...           ...             ...               ...
# 190  2,740.27        254.90%           VED            2.27            52.70%
# 191    163.52          2.80%           VND            2.05            48.10%
# 192    157.58          8.10%           YER            3.79             1.00%
# 193    212.31          9.20%           ZMW            4.63            65.20%
# 194    105.51          0.90%           NaN            3.62            35.50%
#
#     Gasoline Price
# 0           $0.70
# 1           $1.36
# 2           $0.28
# 3           $1.51
# 4           $0.97
# ..             ...
# 190         $0.00
# 191         $0.80
# 192         $0.92
# 193         $1.40
# 194         $1.34
#
# [195 rows x 15 columns]

# %%
#Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).
df.describe()
# Out:
#        Birth Rate  Calling Code  Fertility Rate
# count  189.000000    194.000000      188.000000
# mean    20.214974    360.546392        2.698138
# std      9.945774    323.236419        1.282267
# min      5.900000      1.000000        0.980000
# 25%     11.300000     82.500000        1.705000
# 50%     17.950000    255.500000        2.245000
# 75%     28.750000    506.750000        3.597500
# max     46.080000   1876.000000        6.910000

# %% [markdown]
# ## Ejercicios con loc e iloc

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
#1.Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc
df.loc[:, 'Density\n(P/Km2)':'Agricultural Land( %)']
# Out:
#     Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0                 60           AF                58.10%
# 1                105           AL                43.10%
# 2                 18           DZ                17.40%
# 3                164           AD                40.00%
# 4                 26           AO                47.50%
# ..               ...          ...                   ...
# 190               32           VE                24.50%
# 191              314           VN                39.30%
# 192               56           YE                44.60%
# 193               25           ZM                32.10%
# 194               38           ZW                41.90%
#
# [195 rows x 3 columns]

# %%
#2.Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.
df.loc["Birth Rate"]>30
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #2.Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.
# ----> 2 df.loc["Birth Rate">30]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df.loc[df['Birth Rate'] > 30, 'Birth Rate' ]
# Out:
# 0      32.49
# 4      40.73
# 18     36.22
# 26     37.93
# 27     39.01
# 28     35.74
# 31     35.39
# 33     35.35
# 34     42.17
# 38     31.88
# 39     32.86
# 45     41.18
# 53     33.24
# 54     30.30
# 57     32.34
# 61     31.61
# 62     38.54
# 69     36.36
# 70     35.13
# 96     33.04
# 101    32.66
# 102    34.12
# 105    41.54
# 108    33.69
# 117    37.52
# 125    46.08
# 126    37.91
# 144    31.70
# 150    31.54
# 152    34.52
# 155    33.41
# 159    32.44
# 160    41.75
# 163    35.01
# 166    32.18
# 171    30.76
# 172    36.70
# 175    33.11
# 182    38.14
# 192    30.45
# 193    36.19
# 194    30.68
# Name: Birth Rate, dtype: float64

# %%
#3.Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.
df.loc[df["Fertility Rate"] > 3, ["Country" ,"Capital/Major City", "Fertility Rate"] ]
# Out:
#                               Country Capital/Major City  Fertility Rate
# 0                         Afghanistan              Kabul            4.47
# 2                             Algeria            Algiers            3.02
# 4                              Angola             Luanda            5.52
# 18                              Benin         Porto-Novo            4.84
# 26                       Burkina Faso        Ouagadougou            5.19
# 27                            Burundi          Bujumbura            5.41
# 28                        Ivory Coast       Yamoussoukro            4.65
# 31                           Cameroon            Yaound�            4.57
# 33           Central African Republic             Bangui            4.72
# 34                               Chad          N'Djamena            5.75
# 38                            Comoros    Moroni, Comoros            4.21
# 39              Republic of the Congo        Brazzaville            4.43
# 45   Democratic Republic of the Congo           Kinshasa            5.92
# 51                              Egypt              Cairo            3.33
# 53                  Equatorial Guinea             Malabo            4.51
# 54                            Eritrea             Asmara            4.06
# 57                           Ethiopia        Addis Ababa            4.25
# 61                              Gabon         Libreville            3.97
# 62                         The Gambia             Banjul            5.22
# 65                              Ghana              Accra            3.87
# 69                             Guinea            Conakry            4.70
# 70                      Guinea-Bissau             Bissau            4.48
# 80                               Iraq            Baghdad            3.67
# 82                             Israel          Jerusalem            3.09
# 88                              Kenya            Nairobi            3.49
# 89                           Kiribati       South Tarawa            3.57
# 91                         Kyrgyzstan            Bishkek            3.30
# 95                            Lesotho             Maseru            3.14
# 96                            Liberia           Monrovia            4.32
# 101                        Madagascar       Antananarivo            4.08
# 102                            Malawi           Lilongwe            4.21
# 105                              Mali             Bamako            5.88
# 107                  Marshall Islands             Majuro            4.05
# 108                        Mauritania         Nouakchott            4.56
# 111    Federated States of Micronesia            Palikir            3.05
# 117                        Mozambique             Maputo            4.85
# 119                           Namibia           Windhoek            3.40
# 125                             Niger             Niamey            6.91
# 126                           Nigeria              Abuja            5.39
# 131                          Pakistan          Islamabad            3.51
# 135                  Papua New Guinea       Port Moresby            3.56
# 144                            Rwanda             Kigali            4.04
# 148                             Samoa               Apia            3.88
# 150                      S�����������              S����            4.32
# 152                           Senegal              Dakar            4.63
# 155                      Sierra Leone           Freetown            4.26
# 159                   Solomon Islands            Honiara            4.40
# 160                           Somalia          Mogadishu            6.07
# 163                       South Sudan               Juba            4.70
# 166                             Sudan           Khartoum            4.41
# 171                        Tajikistan           Dushanbe            3.59
# 172                          Tanzania             Dodoma            4.89
# 174                        East Timor               Dili            4.02
# 175                              Togo               Lom�            4.32
# 176                             Tonga           Nuku����            3.56
# 182                            Uganda            Kampala            4.96
# 189                           Vanuatu          Port Vila            3.78
# 192                             Yemen              Sanaa            3.79
# 193                            Zambia             Lusaka            4.63
# 194                          Zimbabwe             Harare            3.62

# %%
#4.Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc
df.loc[df["Abbreviation"]== "AL", "Gasoline Price"]
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %%
#5.Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.
df.loc[df["Capital/Major City"]== "Tirana", :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 1             9,000       11.78         355.0             Tirana
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 1         4,536  119.05          1.40%           ALL            1.62
#
#   Forested Area (%) Gasoline Price
# 1            28.10%         $1.36

# %%
#6.Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.
df.loc[df["CPI"] == 128.85 ,:]
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Armed Forces size, Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price]
# Index: []

# %%
#7.Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.
df.loc[df["Abbreviation"]== "AD", "Density\n(P/Km2)"]
# Out:
# 3    164
# Name: Density\n(P/Km2), dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
#8.Selecciona las columnas "Country" y "Co2-Emissions"
df.loc[:,['Country','Co2-Emissions']]
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]

# %%
#9.Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").
df.loc[df["CPI Change (%)"] == '2.00%' ,:]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 2           317,000       24.28         213.0            Algiers
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 2       150,006  151.36          2.00%           DZD            3.02
#
#   Forested Area (%) Gasoline Price
# 2             0.80%         $0.28

# %%
#10.Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.
df.loc[df["Abbreviation"]== "AF", ["Birth Rate",'Country']]
# Out:
#    Birth Rate      Country
# 0       32.49  Afghanistan

# %%
#11.Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.
df.iloc[:,3:5]
# Out:
#     Agricultural Land( %) Land Area(Km2)
# 0                  58.10%        652,230
# 1                  43.10%         28,748
# 2                  17.40%      2,381,741
# 3                  40.00%            468
# 4                  47.50%      1,246,700
# ..                    ...            ...
# 190                24.50%        912,050
# 191                39.30%        331,210
# 192                44.60%        527,968
# 193                32.10%        752,618
# 194                41.90%        390,757
#
# [195 rows x 2 columns]

# %%
#12.Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.
df.iloc[:,[1,3,6]]
# Out:
#     Density\n(P/Km2) Agricultural Land( %)  Birth Rate
# 0                 60                58.10%       32.49
# 1                105                43.10%       11.78
# 2                 18                17.40%       24.28
# 3                164                40.00%        7.20
# 4                 26                47.50%       40.73
# ..               ...                   ...         ...
# 190               32                24.50%       17.88
# 191              314                39.30%       16.75
# 192               56                44.60%       30.45
# 193               25                32.10%       36.19
# 194               38                41.90%       30.68
#
# [195 rows x 3 columns]

# %%
#13.Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.
df.iloc[:,0:4]
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
# [195 rows x 4 columns]

# %%
#14.Encuentra el valor en la fila 2 y columna 7 utilizando iloc.
df.iloc[2,7]
# Out:
# 213.0

# %%
#15.Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.
df.iloc[:,[0,2,5]]
# Out:
#          Country Abbreviation Armed Forces size
# 0    Afghanistan           AF           323,000
# 1        Albania           AL             9,000
# 2        Algeria           DZ           317,000
# 3        Andorra           AD               NaN
# 4         Angola           AO           117,000
# ..           ...          ...               ...
# 190    Venezuela           VE           343,000
# 191      Vietnam           VN           522,000
# 192        Yemen           YE            40,000
# 193       Zambia           ZM            16,000
# 194     Zimbabwe           ZW            51,000
#
# [195 rows x 3 columns]

# %%
#16.Selecciona las filas 0, 2 y 4 para todas las columnas utilizando iloc.
df.iloc[[0,2,4], :]
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 2      Algeria               18           DZ                17.40%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 2      2,381,741           317,000       24.28         213.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 2            Algiers       150,006  151.36          2.00%           DZD
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 2            3.02             0.80%         $0.28
# 4            5.52            46.30%         $0.97

# %%
#17 Encuentra el valor en la última fila y la última columna utilizando iloc.
df.iloc[-1,-1]
# Out:
# '$1.34 '

# %%
df.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %%
#18.Selecciona las filas 1 a 3 (inclusive) para todas las columnas utilizando iloc.
df.iloc[1:4,:]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
# 2  Algeria               18           DZ                17.40%      2,381,741
# 3  Andorra              164           AD                40.00%            468
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 1         4,536  119.05          1.40%           ALL            1.62
# 2       150,006  151.36          2.00%           DZD            3.02
# 3           469     NaN            NaN           EUR            1.27
#
#   Forested Area (%) Gasoline Price
# 1            28.10%         $1.36
# 2             0.80%         $0.28
# 3            34.00%         $1.51

# %%
#19.Selecciona todas las filas para las columnas 1, 4 y 6 utilizando iloc.
df.iloc[:,[1,4,6]]
# Out:
#     Density\n(P/Km2) Land Area(Km2)  Birth Rate
# 0                 60        652,230       32.49
# 1                105         28,748       11.78
# 2                 18      2,381,741       24.28
# 3                164            468        7.20
# 4                 26      1,246,700       40.73
# ..               ...            ...         ...
# 190               32        912,050       17.88
# 191              314        331,210       16.75
# 192               56        527,968       30.45
# 193               25        752,618       36.19
# 194               38        390,757       30.68
#
# [195 rows x 3 columns]

# %%
#20.Encuentra el valor en la fila 4 y columna 2 utilizando iloc.
df.iloc[4,2]
# Out:
# 'AO'

# %%
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]
